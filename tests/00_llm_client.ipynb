# %%
import sys

sys.path.append("..")

# %%
from utils.llm_client import LLMClient

model = LLMClient(provider="google", model="gemini-2.0-flash-exp", max_retries=3)

# %%
messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant."
    },
    {
        "role": "user",
        "content": "Hello, how are you?"
    }
]

model.chat(messages)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   avg_logprobs=-0.12026911228895187,
#   content=Content(
#     parts=[
#       Part(
#         text="""I am doing well, thank you for asking! How are you today?
# """
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>
# )] create_time=None model_version='gemini-2.0-flash-exp' prompt_feedback=None response_id='I_RfadDbEMe-g8UP1pDXyQc' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=16,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=16
#     ),
#   ],
#   prompt_token_count=12,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=12
#     ),
#   ],
#   total_token_count=28
# ) automatic_function_calling_history=[] parsed=None
# GenerateContentResponse(
# ...
